# %%
import pandas as pd
import numpy as np
import json

# %%
#open saved files and preview
df_2000 = pd.read_csv("Data/final_tmdb_data_2000.csv.gz", low_memory = False)
df_2000.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres  \
# 0         NaN                                                NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                                homepage        id original_language  \
# 0                                   NaN       NaN               NaN
# 1                                   NaN   62127.0                en
# 2                                   NaN  110977.0                en
# 3                                   NaN  442869.0                hi
# 4  http://www.wkw-inthemoodforlove.com/     843.0                cn
#
#     original_title  ...     revenue  runtime  \
# 0              NaN  ...         NaN      NaN
# 1  The Fantasticks  ...         0.0     86.0
# 2    For the Cause  ...         0.0    100.0
# 3             Gang  ...         0.0    152.0
# 4             花樣年華  ...  12854953.0     99.0
#
#                                     spoken_languages    status  \
# 0                                                NaN       NaN
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 4  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
#
#                                              tagline                 title  \
# 0                                                NaN                   NaN
# 1      Try to remember the first time magic happened       The Fantasticks
# 2       The ultimate showdown on a forbidden planet.         For the Cause
# 3                                                NaN                  Gang
# 4  Feel the heat, keep the feeling burning, let t...  In the Mood for Love
#
#    video  vote_average vote_count certification
# 0    NaN           NaN        NaN           NaN
# 1    0.0         5.500       22.0           NaN
# 2    0.0         5.100        8.0           NaN
# 3    0.0         0.000        0.0           NaN
# 4    0.0         8.108     1956.0            PG
#
# [5 rows x 26 columns]

# %%
df_2001 = pd.read_csv("Data/final_tmdb_data_2001.csv.gz", low_memory = False)
df_2001.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0035423    0.0  /ab5yL8zgRotrICzGbEl10z24N71.jpg                   NaN
# 2  tt0114447    0.0                               NaN                   NaN
# 3  tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg                   NaN
# 4  tt0118652    0.0  /mWxJEFRMvkG4UItYJkRDMgWQ08Y.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  48000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...      NaN
# 2         0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...      NaN
# 3  22000000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...      NaN
# 4   1000000.0  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...      NaN
#
#          id original_language         original_title  ...     revenue  \
# 0       NaN               NaN                    NaN  ...         NaN
# 1   11232.0                en         Kate & Leopold  ...  76019048.0
# 2  151007.0                en       The Silent Force  ...         0.0
# 3   10696.0                en                Glitter  ...   5271666.0
# 4   17140.0                en  The Attic Expeditions  ...         0.0
#
#    runtime                                   spoken_languages    status  \
# 0      NaN                                                NaN       NaN
# 1    118.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2     90.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3    104.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4    100.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline                  title  \
# 0                                                NaN                    NaN
# 1  If they lived in the same century they'd be pe...         Kate & Leopold
# 2  They left him for dead... They should have fin...       The Silent Force
# 3   In music she found her dream, her love, herself.                Glitter
# 4  His search for peace of mind... will leave his...  The Attic Expeditions
#
#    video  vote_average vote_count certification
# 0    NaN           NaN        NaN           NaN
# 1    0.0           6.3     1137.0         PG-13
# 2    0.0           5.0        3.0           NaN
# 3    0.0           4.6      117.0         PG-13
# 4    0.0           5.1       28.0             R
#
# [5 rows x 26 columns]

# %%
#combine/concat dfs into one
#source: https://pandas.pydata.org/docs/user_guide/merging.html
frames = [df_2000, df_2001]

tmdb_results = pd.concat(frames)

# %%
#review files merged
tmdb_results.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres  \
# 0         NaN                                                NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                                homepage        id original_language  \
# 0                                   NaN       NaN               NaN
# 1                                   NaN   62127.0                en
# 2                                   NaN  110977.0                en
# 3                                   NaN  442869.0                hi
# 4  http://www.wkw-inthemoodforlove.com/     843.0                cn
#
#     original_title  ...     revenue  runtime  \
# 0              NaN  ...         NaN      NaN
# 1  The Fantasticks  ...         0.0     86.0
# 2    For the Cause  ...         0.0    100.0
# 3             Gang  ...         0.0    152.0
# 4             花樣年華  ...  12854953.0     99.0
#
#                                     spoken_languages    status  \
# 0                                                NaN       NaN
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 4  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
#
#                                              tagline                 title  \
# 0                                                NaN                   NaN
# 1      Try to remember the first time magic happened       The Fantasticks
# 2       The ultimate showdown on a forbidden planet.         For the Cause
# 3                                                NaN                  Gang
# 4  Feel the heat, keep the feeling burning, let t...  In the Mood for Love
#
#    video  vote_average vote_count certification
# 0    NaN           NaN        NaN           NaN
# 1    0.0         5.500       22.0           NaN
# 2    0.0         5.100        8.0           NaN
# 3    0.0         0.000        0.0           NaN
# 4    0.0         8.108     1956.0            PG
#
# [5 rows x 26 columns]

# %%
tmdb_results.to_csv('Data/tmdb_results_combined.csv.gz', compression='gzip',index=False)

# %%
#check df info
tmdb_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3442 entries, 0 to 2236
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                3442 non-null   object
#  1   adult                  3440 non-null   float64
#  2   backdrop_path          1804 non-null   object
#  3   belongs_to_collection  256 non-null    object
#  4   budget                 3440 non-null   float64
#  5   genres                 3440 non-null   object
#  6   homepage               258 non-null    object
#  7   id                     3440 non-null   float64
#  8   original_language      3440 non-null   object
#  9   original_title         3440 non-null   object
#  10  overview               3366 non-null   object
#  11  popularity             3440 non-null   float64
#  12  poster_path            3052 non-null   object
#  13  production_companies   3440 non-null   object
#  14  production_countries   3440 non-null   object
#  15  release_date           3417 non-null   object
#  16  revenue                3440 non-null   float64
#  17  runtime                3440 non-null   float64
#  18  spoken_languages       3440 non-null   object
#  19  status                 3440 non-null   object
#  20  tagline                1495 non-null   object
#  21  title                  3440 non-null   object
#  22  video                  3440 non-null   float64
#  23  vote_average           3440 non-null   float64
#  24  vote_count             3440 non-null   float64
#  25  certification          1167 non-null   object
# dtypes: float64(9), object(17)
# memory usage: 726.0+ KB

# %%
#movies with values > 0 for budget OR revenue
#exclude any movies with 0's for budget AND revenue

filter_budget = tmdb_results['budget']>0
filter_revenue = tmdb_results['revenue']>0
tmdb_results.loc[filter_budget | filter_revenue]
# Out:
#         imdb_id  adult                     backdrop_path  \
# 1     tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 4     tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# 6     tt0119273    0.0  /fClJrAmJQ90zg9gWnfHVYSMiDTv.jpg
# 10    tt0120263    0.0  /ynXVuylP8upazjz8lrqb1PEMkdR.jpg
# 11    tt0120467    0.0  /knok3mNReKqPTplnnqz7E4dd7mD.jpg
# ...         ...    ...                               ...
# 2204  tt0288192    0.0  /lDmQKPHzBiTpN3V1t28VkgciQZ1.jpg
# 2224  tt0290326    0.0  /nWgnU0B3UrPieO5jU5eTK4htWLj.jpg
# 2225  tt0290329    0.0  /nFV71P9O6IsNUjveaeLfmzHR6hL.jpg
# 2226  tt0290332    0.0  /4CuHVkRiZU5y5J05Nf4Cw6vG6qF.jpg
# 2229  tt0290662    0.0  /2ajQNGbCvzN0xWviAQkjHZsnU68.jpg
#
#                                   belongs_to_collection      budget  \
# 1                                                   NaN  10000000.0
# 4                                                   NaN    150000.0
# 6     {'id': 141086, 'name': 'Heavy Metal Collection...  15000000.0
# 10                                                  NaN         0.0
# 11                                                  NaN    120000.0
# ...                                                 ...         ...
# 2204                                                NaN    100000.0
# 2224                                                NaN         0.0
# 2225                                                NaN     60400.0
# 2226                                                NaN   7000000.0
# 2229                                                NaN         0.0
#
#                                                  genres  \
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 4     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 6     [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 10    [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 11    [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# ...                                                 ...
# 2204                      [{'id': 18, 'name': 'Drama'}]
# 2224  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# 2225  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2226  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 2229  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
#
#                                                homepage        id  \
# 1                                                   NaN   62127.0
# 4                  http://www.wkw-inthemoodforlove.com/     843.0
# 6                                                   NaN   16225.0
# 10                                                  NaN   34070.0
# 11                                                  NaN   19085.0
# ...                                                 ...       ...
# 2204                                                NaN  274523.0
# 2224                                                NaN   64880.0
# 2225                                                NaN    4241.0
# 2226                                                NaN   13408.0
# 2229  http://www.cine.co.jp/english/works/e_hush/ind...   26895.0
#
#      original_language              original_title  ...     revenue  runtime  \
# 1                   en             The Fantasticks  ...         0.0     86.0
# 4                   cn                        花樣年華  ...  12854953.0     99.0
# 6                   en            Heavy Metal 2000  ...         0.0     88.0
# 10                  sv  Sånger från andra våningen  ...     80334.0     98.0
# 11                  en                      Vulgar  ...     14904.0     87.0
# ...                ...                         ...  ...         ...      ...
# 2204                en         Return to Innocence  ...         0.0    110.0
# 2224                hi                     Tum Bin  ...   1486992.0    158.0
# 2225                ja                       ビジターQ  ...         0.0     84.0
# 2226                en                    The Wash  ...  10229331.0     93.0
# 2229                ja                       ハッシュ!  ...     52462.0    135.0
#
#                                        spoken_languages    status  \
# 1     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4     [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 6     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 10    [{'english_name': 'Russian', 'iso_639_1': 'ru'...  Released
# 11    [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# ...                                                 ...       ...
# 2204  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2224  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 2225  [{'english_name': 'Japanese', 'iso_639_1': 'ja...  Released
# 2226  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2229  [{'english_name': 'Japanese', 'iso_639_1': 'ja...  Released
#
#                                                 tagline  \
# 1         Try to remember the first time magic happened
# 4     Feel the heat, keep the feeling burning, let t...
# 6     not to survive the fight in the external world...
# 10                                                  NaN
# 11     Everyone loves a clown... some more than others.
# ...                                                 ...
# 2204  They took his innocence when he was seven year...
# 2224                             Love Will Find the Way
# 2225  The only thing stranger than this family is......
# 2226  When you're down 'n dirty, it all comes out in...
# 2229       Two guys, a girl, and the desire for a baby.
#
#                             title  video  vote_average vote_count  \
# 1                 The Fantasticks    0.0         5.500       22.0
# 4            In the Mood for Love    0.0         8.108     1956.0
# 6                Heavy Metal 2000    0.0         6.093      156.0
# 10    Songs from the Second Floor    0.0         7.242      215.0
# 11                         Vulgar    0.0         5.400       42.0
# ...                           ...    ...           ...        ...
# 2204          Return to Innocence    0.0         6.900       49.0
# 2224                      Tum Bin    0.0         7.200       15.0
# 2225                    Visitor Q    0.0         6.500      374.0
# 2226                     The Wash    0.0         4.949       79.0
# 2229                        Hush!    0.0         7.000       11.0
#
#      certification
# 1              NaN
# 4               PG
# 6                R
# 10             NaN
# 11               R
# ...            ...
# 2204           NaN
# 2224           NaN
# 2225             R
# 2226           NaN
# 2229           NaN
#
# [917 rows x 26 columns]

# %%
tmdb_results['certification'].value_counts()
# Out:
# R          674
# PG-13      272
# PG          92
# NR          88
# G           32
# NC-17        6
# -            2
# Unrated      1
# Name: certification, dtype: int64

# %%
#movies in each of the certification categories (G/PG/PG-13/R)

filter_G = tmdb_results['certification']=='G'
filter_PG = tmdb_results['certification']=='PG'
filter_PG13 = tmdb_results['certification']=='PG-13'
filter_R = tmdb_results['certification']=='R'

# %%
#certified G
tmdb_results[filter_G]
# Out:
#         imdb_id  adult                     backdrop_path  \
# 13    tt0120630    0.0  /sPAwM8WxMdXNlqeP4F9DMe9LYoY.jpg
# 20    tt0120917    0.0  /neH7GNmzMs1BDLqHXOnTuB04dNh.jpg
# 24    tt0123055    0.0                               NaN
# 275   tt0192255    0.0  /xiVZGT0kKT5wCy7VaYuf5rr6Fnu.jpg
# 383   tt0205461    0.0  /c4uxjS8iAiNwKzFG2SGBmS0EDlp.jpg
# 418   tt0208298    0.0  /guTKlQh7Na7bec8SoAzSfYQWaUK.jpg
# 446   tt0211181    0.0  /eqZ5t82asfprFcNS56eVruNT5G5.jpg
# 469   tt0213203    0.0  /9yxIBACv6GZs9JrhizDW6SEYaNu.jpg
# 565   tt0220099    0.0  /uMoSM7r4dst4e5aFUhDEDPyh1hL.jpg
# 692   tt0235679    0.0  /6X3qdsHcwu06GiiXwwNRWzfJ5oJ.jpg
# 931   tt0263118    0.0                               NaN
# 993   tt0270560    0.0  /xnOUkH3RcAKDajBIXLuntiPkkO8.jpg
# 1160  tt1291055    0.0  /5KwDfIM7UO2vPXr4E7JEmeiFxwU.jpg
# 100   tt0198781    0.0  /vUTVUdfbsY4DePCYzxxDMXKp6v6.jpg
# 126   tt0206367    0.0  /8YAEyzviBTURPYRDkPeZGqyMG0z.jpg
# 399   tt0247638    0.0  /gHtCBCQrzT6MvCylcvgFWPMZ1E2.jpg
# 490   tt0255055    0.0                               NaN
# 585   tt0265632    0.0  /nl9qQqEwt0g3LoNZTzp8tTIM5Dz.jpg
# 619   tt0268397    0.0  /xOyHKUFEhvogSHnDbsa5E7ZYx9D.jpg
# 687   tt0273799    0.0  /ziINAUKAi1W74PffqDdBPk9E62l.jpg
# 721   tt0276198    0.0                               NaN
# 965   tt0291959    0.0  /eB7NQzmfMLNMcjmQsLeoZ3rTjiz.jpg
# 990   tt0293854    0.0  /pu4qTZdFaUfXGjepFDw94zMxJs6.jpg
# 1240  tt0810831    0.0  /foJtMkj948xDdfKkAemGplkQ9ly.jpg
# 1387  tt0198781    0.0  /vUTVUdfbsY4DePCYzxxDMXKp6v6.jpg
# 1413  tt0206367    0.0  /8YAEyzviBTURPYRDkPeZGqyMG0z.jpg
# 1686  tt0247638    0.0  /gHtCBCQrzT6MvCylcvgFWPMZ1E2.jpg
# 1777  tt0255055    0.0                               NaN
# 1872  tt0265632    0.0  /nl9qQqEwt0g3LoNZTzp8tTIM5Dz.jpg
# 1906  tt0268397    0.0  /xOyHKUFEhvogSHnDbsa5E7ZYx9D.jpg
# 1974  tt0273799    0.0  /ziINAUKAi1W74PffqDdBPk9E62l.jpg
# 2008  tt0276198    0.0                               NaN
#
#                                   belongs_to_collection       budget  \
# 13    {'id': 718551, 'name': 'Chicken Run Collection...   45000000.0
# 20    {'id': 178117, 'name': "The Emperor's New Groo...  100000000.0
# 24                                                  NaN          0.0
# 275                                                 NaN   35000000.0
# 383                                                 NaN   19000000.0
# 418                                                 NaN          0.0
# 446   {'id': 124916, 'name': '101 Dalmatians (Live-A...   85000000.0
# 469   {'id': 57129, 'name': 'Rugrats Collection', 'p...   30000000.0
# 565                                                 NaN   30000000.0
# 692   {'id': 34055, 'name': 'Pokémon Collection', 'p...   16000000.0
# 931                                                 NaN          0.0
# 993                                                 NaN          0.0
# 1160  {'id': 39244, 'name': 'Digimon Collection', 'p...          0.0
# 100   {'id': 137696, 'name': 'Monsters, Inc. Collect...  115000000.0
# 126                                                 NaN          0.0
# 399   {'id': 107674, 'name': 'The Princess Diaries C...   37000000.0
# 490                                                 NaN          0.0
# 585   {'id': 421084, 'name': 'Recess Collection', 'p...   10000000.0
# 619                                                 NaN   25000000.0
# 687                                                 NaN   25000000.0
# 721                                                 NaN          0.0
# 965   {'id': 416908, 'name': 'O Grilo Feliz', 'poste...          0.0
# 990   {'id': 427113, 'name': 'Little Bear', 'poster_...          0.0
# 1240  {'id': 39244, 'name': 'Digimon Collection', 'p...          0.0
# 1387  {'id': 137696, 'name': 'Monsters, Inc. Collect...  115000000.0
# 1413                                                NaN          0.0
# 1686  {'id': 107674, 'name': 'The Princess Diaries C...   37000000.0
# 1777                                                NaN          0.0
# 1872  {'id': 421084, 'name': 'Recess Collection', 'p...   10000000.0
# 1906                                                NaN   25000000.0
# 1974                                                NaN   25000000.0
# 2008                                                NaN          0.0
#
#                                                  genres  \
# 13    [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 20    [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
# 24    [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 275   [{'id': 10751, 'name': 'Family'}, {'id': 12, '...
# 383   [{'id': 16, 'name': 'Animation'}, {'id': 18, '...
# 418   [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 446   [{'id': 10751, 'name': 'Family'}, {'id': 35, '...
# 469   [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 565   [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 692   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 931   [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 993   [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 1160  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 100   [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 126   [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 399   [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 490   [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 585   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 619   [{'id': 10751, 'name': 'Family'}, {'id': 28, '...
# 687   [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 721   [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 965   [{'id': 28, 'name': 'Action'}, {'id': 16, 'nam...
# 990   [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 1240                  [{'id': 16, 'name': 'Animation'}]
# 1387  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1413  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 1686  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 1777  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 1872  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1906  [{'id': 10751, 'name': 'Family'}, {'id': 28, '...
# 1974  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 2008  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
#
#                                                homepage        id  \
# 13                                                  NaN    7443.0
# 20                                                  NaN   11688.0
# 24                                                  NaN  248740.0
# 275                                                 NaN   24100.0
# 383                                                 NaN   16110.0
# 418                                                 NaN   30628.0
# 446                                                 NaN   10481.0
# 469                                                 NaN   16340.0
# 565                                                 NaN   15655.0
# 692   https://www.warnerbros.com/movies/pokemon-3-movie   10991.0
# 931                                                 NaN  285320.0
# 993                                                 NaN   34729.0
# 1160                                                NaN   98299.0
# 100               http://movies.disney.com/monsters-inc     585.0
# 126                                                 NaN   54491.0
# 399                                                 NaN    9880.0
# 490                                                 NaN   76692.0
# 585                                                 NaN   19405.0
# 619                                                 NaN   12589.0
# 687                                                 NaN   34549.0
# 721                                                 NaN   64088.0
# 965                                                 NaN  182496.0
# 990   http://www.nelvana.com/show/200/little-bear-th...   33371.0
# 1240                                                NaN   36200.0
# 1387              http://movies.disney.com/monsters-inc     585.0
# 1413                                                NaN   54491.0
# 1686                                                NaN    9880.0
# 1777                                                NaN   76692.0
# 1872                                                NaN   19405.0
# 1906                                                NaN   12589.0
# 1974                                                NaN   34549.0
# 2008                                                NaN   64088.0
#
#      original_language                                     original_title  \
# 13                  en                                        Chicken Run
# 20                  en                           The Emperor's New Groove
# 24                  en                         The Elf Who Didn't Believe
# 275                 en                                 The Little Vampire
# 383                 en                      Thomas and the Magic Railroad
# 418                 en                                  The Miracle Maker
# 446                 en                                     102 Dalmatians
# 469                 en                        Rugrats in Paris: The Movie
# 565                 en                                   The Tigger Movie
# 692                 ja                           劇場版ポケットモンスター 結晶塔の帝王 エンテイ
# 931                 en                              The Best of Dr. Seuss
# 993                 en                                Our Lips Are Sealed
# 1160                ja  デジモンアドベンチャー02 前編・デジモンハリケーン上陸!!／後編・超絶進化!!黄金のデジメンタル
# 100                 en                                     Monsters, Inc.
# 126                 en                            The Trumpet Of The Swan
# 399                 en                               The Princess Diaries
# 490                 en                  IMAX - China: The Panda Adventure
# 585                 en                               Recess: School's Out
# 619                 en                          Jimmy Neutron: Boy Genius
# 687                 en                              Max Keeble's Big Move
# 721                 en                                        Horse Crazy
# 965                 pt                                      O Grilo Feliz
# 990                 en                              The Little Bear Movie
# 1240                ja                                 デジモンテイマーズ 冒険者たちの戦い
# 1387                en                                     Monsters, Inc.
# 1413                en                            The Trumpet Of The Swan
# 1686                en                               The Princess Diaries
# 1777                en                  IMAX - China: The Panda Adventure
# 1872                en                               Recess: School's Out
# 1906                en                          Jimmy Neutron: Boy Genius
# 1974                en                              Max Keeble's Big Move
# 2008                en                                        Horse Crazy
#
#       ...      revenue  runtime  \
# 13    ...  224834564.0     84.0
# 20    ...  169327687.0     78.0
# 24    ...          0.0     90.0
# 275   ...   27965865.0     95.0
# 383   ...   19748009.0     84.0
# 418   ...          0.0     90.0
# 446   ...  183611771.0    100.0
# 469   ...  103291131.0     78.0
# 565   ...   45554533.0     77.0
# 692   ...   68411275.0     74.0
# 931   ...          0.0     56.0
# 993   ...          0.0     89.0
# 1160  ...          0.0     62.0
# 100   ...  579707738.0     92.0
# 126   ...     100202.0     75.0
# 399   ...  165335153.0    115.0
# 490   ...          0.0     48.0
# 585   ...   44460850.0     82.0
# 619   ...   80936232.0     83.0
# 687   ...   18634654.0     86.0
# 721   ...          0.0     84.0
# 965   ...          0.0     80.0
# 990   ...          0.0     75.0
# 1240  ...          0.0     50.0
# 1387  ...  579707738.0     92.0
# 1413  ...     100202.0     75.0
# 1686  ...  165335153.0    115.0
# 1777  ...          0.0     48.0
# 1872  ...   44460850.0     82.0
# 1906  ...   80936232.0     83.0
# 1974  ...   18634654.0     86.0
# 2008  ...          0.0     84.0
#
#                                        spoken_languages    status  \
# 13    [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 20    [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 24    [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 275   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 383   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 418   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 446   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 469   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 565   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 692   [{'english_name': 'Japanese', 'iso_639_1': 'ja...  Released
# 931                                                  []  Released
# 993   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1160  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 100   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 126   [{'english_name': 'French', 'iso_639_1': 'fr',...  Released
# 399   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 490   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 585   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 619   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 687   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 721                                                  []  Released
# 965   [{'english_name': 'Portuguese', 'iso_639_1': '...  Released
# 990   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1240  [{'english_name': 'Japanese', 'iso_639_1': 'ja...  Released
# 1387  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1413  [{'english_name': 'French', 'iso_639_1': 'fr',...  Released
# 1686  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1777  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1872  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1906  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1974  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2008                                                 []  Released
#
#                                                 tagline  \
# 13    This ain't no chick flick. It's poultry in mot...
# 20                                It's all about... ME!
# 24                                                  NaN
# 275   They're not just best friends, they're blood b...
# 383                 Little Engines CAN Do Big Things...
# 418                                                 NaN
# 446       Meet Two Unlikely Heroes With A Bone To Pick.
# 469                          France never had a chance!
# 565                                                 NaN
# 692             This spring the Unown spells adventure.
# 931                                                 NaN
# 993                                                 NaN
# 1160                                                NaN
# 100                           We Scare Because We Care.
# 126   Sometimes being different helps you to find yo...
# 399                   She rocks. She rules. She reigns.
# 490   An extraordinary journey. An experience of won...
# 585           Saving The World One Playground At A Time
# 619          He may be small, but he's got a big brain!
# 687                               His World. His Rules.
# 721        You're never too young to chase your dreams.
# 965                                                 NaN
# 990                                                 NaN
# 1240                                                NaN
# 1387                          We Scare Because We Care.
# 1413  Sometimes being different helps you to find yo...
# 1686                  She rocks. She rules. She reigns.
# 1777  An extraordinary journey. An experience of won...
# 1872          Saving The World One Playground At A Time
# 1906         He may be small, but he's got a big brain!
# 1974                              His World. His Rules.
# 2008       You're never too young to chase your dreams.
#
#                                                   title  video  vote_average  \
# 13                                          Chicken Run    0.0         6.726
# 20                             The Emperor's New Groove    0.0         7.547
# 24                           The Elf Who Didn't Believe    0.0         4.000
# 275                                  The Little Vampire    0.0         6.801
# 383                       Thomas and the Magic Railroad    0.0         5.464
# 418                                   The Miracle Maker    0.0         5.800
# 446                                      102 Dalmatians    0.0         5.500
# 469                         Rugrats in Paris: The Movie    0.0         6.624
# 565                                    The Tigger Movie    0.0         6.500
# 692                                Pokémon 3: The Movie    0.0         6.438
# 931                               The Best of Dr. Seuss    1.0         8.000
# 993                                 Our Lips Are Sealed    0.0         6.006
# 1160  Digimon Adventure 02 - Hurricane Touchdown! Th...    0.0         7.214
# 100                                      Monsters, Inc.    0.0         7.821
# 126                             The Trumpet Of The Swan    0.0         5.453
# 399                                The Princess Diaries    0.0         6.930
# 490                          China: The Panda Adventure    0.0         7.000
# 585                                Recess: School's Out    0.0         6.491
# 619                           Jimmy Neutron: Boy Genius    0.0         5.910
# 687                               Max Keeble's Big Move    0.0         5.706
# 721                                         Horse Crazy    0.0         0.000
# 965                                   The Happy Cricket    0.0         4.500
# 990                               The Little Bear Movie    0.0         6.545
# 1240              Digimon Tamers: Battle of Adventurers    0.0         6.900
# 1387                                     Monsters, Inc.    0.0         7.821
# 1413                            The Trumpet Of The Swan    0.0         5.453
# 1686                               The Princess Diaries    0.0         6.930
# 1777                         China: The Panda Adventure    0.0         7.000
# 1872                               Recess: School's Out    0.0         6.491
# 1906                          Jimmy Neutron: Boy Genius    0.0         5.910
# 1974                              Max Keeble's Big Move    0.0         5.706
# 2008                                        Horse Crazy    0.0         0.000
#
#      vote_count certification
# 13       4106.0             G
# 20       5596.0             G
# 24          1.0             G
# 275       341.0             G
# 383        55.0             G
# 418        30.0             G
# 446      1151.0             G
# 469       394.0             G
# 565       467.0             G
# 692       512.0             G
# 931         2.0             G
# 993       234.0             G
# 1160       28.0             G
# 100     15859.0             G
# 126        53.0             G
# 399      4238.0             G
# 490         2.0             G
# 585       274.0             G
# 619       732.0             G
# 687       126.0             G
# 721         0.0             G
# 965        10.0             G
# 990        11.0             G
# 1240       11.0             G
# 1387    15859.0             G
# 1413       53.0             G
# 1686     4238.0             G
# 1777        2.0             G
# 1872      274.0             G
# 1906      732.0             G
# 1974      126.0             G
# 2008        0.0             G
#
# [32 rows x 26 columns]

# %%
#certified PG
tmdb_results[filter_PG]
# Out:
#         imdb_id  adult                     backdrop_path  \
# 4     tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# 19    tt0120913    0.0  /pniACHS8KDVCldB3BlwL78RIZ7V.jpg
# 22    tt0122459    0.0  /oNOJoW2XoH3shkQxHtOyacJRBCQ.jpg
# 27    tt0130623    0.0  /laeEtakR2pLKu3CeRwB2lU5Y53X.jpg
# 28    tt0131704    0.0  /9K1y8HCokYpuU92jKauiFwu0y7P.jpg
# ...         ...    ...                               ...
# 2108  tt0282589    0.0  /6hBomedYF2lEzHbfKE4k81CkDdd.jpg
# 2112  tt0282768    0.0  /2XVEjzisS34cJy14OsR8d980gYj.jpg
# 2175  tt0286112    0.0  /tkxYmE3HzHy7E39zY3VvQ0k0VLU.jpg
# 2194  tt0287547    0.0                               NaN
# 2195  tt0287635    0.0  /2Ut5lSVXDr2MvuTNa7VgBqTzap3.jpg
#
#                                   belongs_to_collection       budget  \
# 4                                                   NaN     150000.0
# 19                                                  NaN   75000000.0
# 22                                                  NaN   24000000.0
# 27                                                  NaN  127500000.0
# 28                                                  NaN   76000000.0
# ...                                                 ...          ...
# 2108                                                NaN          0.0
# 2112                                                NaN          0.0
# 2175                                                NaN   10000005.0
# 2194                                                NaN    7500000.0
# 2195  {'id': 34055, 'name': 'Pokémon Collection', 'p...          0.0
#
#                                                  genres  \
# 4     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 19    [{'id': 16, 'name': 'Animation'}, {'id': 28, '...
# 22    [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 27    [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 28    [{'id': 10751, 'name': 'Family'}, {'id': 12, '...
# ...                                                 ...
# 2108  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 2112  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2175  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 2194                  [{'id': 16, 'name': 'Animation'}]
# 2195  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
#
#                                              homepage        id  \
# 4                http://www.wkw-inthemoodforlove.com/     843.0
# 19                                                NaN    7450.0
# 22                                                NaN    2621.0
# 27                                                NaN   10567.0
# 28                                                NaN   17711.0
# ...                                               ...       ...
# 2108                                              NaN   36427.0
# 2112                                              NaN   52258.0
# 2175                                              NaN   11770.0
# 2194                                              NaN  795374.0
# 2195  https://www.miramax.com/movie/pokemon-iv-4ever/   12600.0
#
#      original_language                        original_title  ...  \
# 4                   cn                                  花樣年華  ...
# 19                  en                            Titan A.E.  ...
# 22                  en                          Return to Me  ...
# 27                  en                              Dinosaur  ...
# 28                  en  The Adventures of Rocky & Bullwinkle  ...
# ...                ...                                   ...  ...
# 2108                en       I Saw Mommy Kissing Santa Claus  ...
# 2112                en             The Emperor's New Clothes  ...
# 2175                cn                                  少林足球  ...
# 2194                ru                           Man and Cat  ...
# 2195                ja             劇場版ポケットモンスター セレビィ 時を超えた遭遇  ...
#
#           revenue  runtime                                   spoken_languages  \
# 4      12854953.0     99.0  [{'english_name': 'Cantonese', 'iso_639_1': 'c...
# 19     36754634.0     94.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 22     36609995.0    115.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 27    354248063.0     82.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 28     35134820.0     88.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# ...           ...      ...                                                ...
# 2108          0.0    100.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2112          0.0    107.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2175   42776760.0    113.0  [{'english_name': 'Cantonese', 'iso_639_1': 'c...
# 2194          0.0      0.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2195   28023563.0     75.0  [{'english_name': 'Japanese', 'iso_639_1': 'ja...
#
#         status                                            tagline  \
# 4     Released  Feel the heat, keep the feeling burning, let t...
# 19    Released             When Earth Ends, The Adventure Begins.
# 22    Released                   A comedy straight from the heart
# 27    Released            You have never seen anything like this.
# 28    Released            This summer it's not the same old bull.
# ...        ...                                                ...
# 2108  Released      Christmas is coming, and Santa's a dirty rat!
# 2112  Released                                                NaN
# 2175  Released                      Get ready to kick some grass!
# 2194  Released                                                NaN
# 2195  Released                       Best friends. Better heroes.
#
#                                      title  video  vote_average vote_count  \
# 4                     In the Mood for Love    0.0         8.108     1956.0
# 19                              Titan A.E.    0.0         6.592      881.0
# 22                            Return to Me    0.0         6.700      324.0
# 27                                Dinosaur    0.0         6.481     2072.0
# 28    The Adventures of Rocky & Bullwinkle    0.0         4.072      306.0
# ...                                    ...    ...           ...        ...
# 2108       I Saw Mommy Kissing Santa Claus    0.0         5.400       22.0
# 2112             The Emperor's New Clothes    0.0         6.700       32.0
# 2175                        Shaolin Soccer    0.0         7.039     1740.0
# 2194                           Man and Cat    0.0         5.000        1.0
# 2195                         Pokémon 4Ever    0.0         6.399      328.0
#
#      certification
# 4               PG
# 19              PG
# 22              PG
# 27              PG
# 28              PG
# ...            ...
# 2108            PG
# 2112            PG
# 2175            PG
# 2194            PG
# 2195            PG
#
# [92 rows x 26 columns]

# %%
#certified PG13
tmdb_results[filter_PG13]
# Out:
#         imdb_id  adult                     backdrop_path  \
# 17    tt0120755    0.0  /24DZfupDlhXeTchmcOkoGRhP5Vg.jpg
# 18    tt0120903    0.0  /lAFUFuxy74r4dUw2pmxTtzkfSDE.jpg
# 40    tt0138818    0.0                               NaN
# 41    tt0138927    0.0  /5f8tJLrFdcgSpqYi7U58GEkoMF1.jpg
# 45    tt0141926    0.0  /2W1AA5qZXJrR7MJXUgqj49JsLYy.jpg
# ...         ...    ...                               ...
# 1997  tt0275527    0.0                               NaN
# 2024  tt0277027    0.0  /mOsg2l9zq315ouw55rbNATSwgU1.jpg
# 2095  tt0281680    0.0                               NaN
# 2149  tt0284233    0.0                               NaN
# 2235  tt0290858    0.0                               NaN
#
#                                   belongs_to_collection       budget  \
# 17    {'id': 87359, 'name': 'Mission: Impossible Col...  125000000.0
# 18    {'id': 748, 'name': 'X-Men Collection', 'poste...   75000000.0
# 40                                                  NaN          0.0
# 41                                                  NaN          0.0
# 45                                                  NaN   62000000.0
# ...                                                 ...          ...
# 1997                                                NaN          0.0
# 2024                                                NaN   22000000.0
# 2095                                                NaN     600000.0
# 2149                                                NaN          0.0
# 2235                                                NaN          0.0
#
#                                                  genres  \
# 17    [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 18    [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 40                        [{'id': 18, 'name': 'Drama'}]
# 41                        [{'id': 18, 'name': 'Drama'}]
# 45    [{'id': 10752, 'name': 'War'}, {'id': 18, 'nam...
# ...                                                 ...
# 1997                      [{'id': 18, 'name': 'Drama'}]
# 2024                      [{'id': 18, 'name': 'Drama'}]
# 2095  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 2149                      [{'id': 18, 'name': 'Drama'}]
# 2235                      [{'id': 18, 'name': 'Drama'}]
#
#                                              homepage        id  \
# 17                                                NaN     955.0
# 18    https://www.20thcenturystudios.com/movies/x-men   36657.0
# 40                                                NaN  651895.0
# 41                                                NaN   65736.0
# 45                              http://www.u-571.com/    3536.0
# ...                                               ...       ...
# 1997                                              NaN  623543.0
# 2024                                              NaN   10950.0
# 2095                                              NaN   43664.0
# 2149                                              NaN   70694.0
# 2235                                              NaN  176530.0
#
#      original_language          original_title  ...      revenue  runtime  \
# 17                  en  Mission: Impossible II  ...  546388105.0    123.0
# 18                  en                   X-Men  ...  296339527.0    104.0
# 40                  en        The Hiding Place  ...          0.0     97.0
# 41                  en              Waterproof  ...          0.0     94.0
# 45                  en                   U-571  ...  127666415.0    116.0
# ...                ...                     ...  ...          ...      ...
# 1997                en      A Month of Sundays  ...          0.0     92.0
# 2024                en                I Am Sam  ...   92542418.0    132.0
# 2095                en     The Bread, My Sweet  ...    1023156.0    105.0
# 2149                en              The Keyman  ...          0.0     90.0
# 2235                bm  Sia, le rêve du python  ...          0.0     96.0
#
#                                        spoken_languages    status  \
# 17    [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 18    [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 40    [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 41                                                   []  Released
# 45    [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# ...                                                 ...       ...
# 1997  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2024  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2095  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2149  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2235  [{'english_name': 'Bambara', 'iso_639_1': 'bm'...  Released
#
#                                                 tagline  \
# 17                         Expect the impossible again.
# 18                          Trust a few. Fear the rest.
# 40    The only one who knows can't be trusted and is...
# 41    Eli Zeal is about to learn that to err is huma...
# 45    Heroes are ordinary men who do extraordinary t...
# ...                                                 ...
# 1997  It's easy to forgive, sometimes it just takes ...
# 2024                              Love is all you need.
# 2095         In Italian a good man is a piece of bread.
# 2149                            A Journey to Redemption
# 2235                                                NaN
#
#                             title  video  vote_average vote_count  \
# 17         Mission: Impossible II    0.0         6.108     5448.0
# 18                          X-Men    0.0         6.985     9795.0
# 40               The Hiding Place    0.0         4.000        1.0
# 41                     Waterproof    0.0         6.000        4.0
# 45                          U-571    0.0         6.437      966.0
# ...                           ...    ...           ...        ...
# 1997           A Month of Sundays    0.0         3.500        2.0
# 2024                     I Am Sam    0.0         7.568     1922.0
# 2095          The Bread, My Sweet    0.0         5.200       11.0
# 2149                   The Keyman    0.0         5.200        2.0
# 2235  Sia, the Myth of the Python    0.0         5.800        4.0
#
#      certification
# 17           PG-13
# 18           PG-13
# 40           PG-13
# 41           PG-13
# 45           PG-13
# ...            ...
# 1997         PG-13
# 2024         PG-13
# 2095         PG-13
# 2149         PG-13
# 2235         PG-13
#
# [272 rows x 26 columns]

# %%
#certified R
tmdb_results[filter_R]
# Out:
#         imdb_id  adult                     backdrop_path  \
# 5     tt0118852    0.0                               NaN
# 6     tt0119273    0.0  /fClJrAmJQ90zg9gWnfHVYSMiDTv.jpg
# 7     tt0119495    0.0                               NaN
# 11    tt0120467    0.0  /knok3mNReKqPTplnnqz7E4dd7mD.jpg
# 16    tt0120753    0.0                               NaN
# ...         ...    ...                               ...
# 2178  tt0286484    0.0                               NaN
# 2182  tt0286751    0.0  /2ffEo7Aifb0maJTzVY3FWOZqWp6.jpg
# 2205  tt0288215    0.0                               NaN
# 2222  tt0290082    0.0                               NaN
# 2225  tt0290329    0.0  /nFV71P9O6IsNUjveaeLfmzHR6hL.jpg
#
#                                   belongs_to_collection      budget  \
# 5                                                   NaN         0.0
# 6     {'id': 141086, 'name': 'Heavy Metal Collection...  15000000.0
# 7                                                   NaN         0.0
# 11                                                  NaN    120000.0
# 16                                                  NaN   8000000.0
# ...                                                 ...         ...
# 2178                                                NaN         0.0
# 2182                                                NaN  25000000.0
# 2205                                                NaN         0.0
# 2222                                                NaN         0.0
# 2225                                                NaN     60400.0
#
#                                                  genres homepage        id  \
# 5                         [{'id': 18, 'name': 'Drama'}]      NaN   49511.0
# 6     [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      NaN   16225.0
# 7     [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...      NaN   51181.0
# 11    [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...      NaN   19085.0
# 16    [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...      NaN     318.0
# ...                                                 ...      ...       ...
# 2178  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...      NaN  224207.0
# 2182  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...      NaN   27324.0
# 2205  [{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'na...      NaN   54129.0
# 2222                     [{'id': 35, 'name': 'Comedy'}]      NaN   26468.0
# 2225  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN    4241.0
#
#      original_language            original_title  ...   revenue  runtime  \
# 5                   en            Chinese Coffee  ...       0.0     99.0
# 6                   en          Heavy Metal 2000  ...       0.0     88.0
# 7                   en                  Love 101  ...       0.0     86.0
# 11                  en                    Vulgar  ...   14904.0     87.0
# 16                  en  The Million Dollar Hotel  ...  105983.0    122.0
# ...                ...                       ...  ...       ...      ...
# 2178                en               Crime Scene  ...       0.0     91.0
# 2182                ja                        回路  ...  318451.0    119.0
# 2205                en               Shadow Fury  ...       0.0     89.0
# 2222                en         Survivors Exposed  ...       0.0     93.0
# 2225                ja                     ビジターQ  ...       0.0     84.0
#
#                                        spoken_languages    status  \
# 5     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 6     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 7                                                    []  Released
# 11    [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 16    [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# ...                                                 ...       ...
# 2178  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2182  [{'english_name': 'Japanese', 'iso_639_1': 'ja...  Released
# 2205  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2222  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2225  [{'english_name': 'Japanese', 'iso_639_1': 'ja...  Released
#
#                                                 tagline  \
# 5     There's a fine line between friendship and bet...
# 6     not to survive the fight in the external world...
# 7                                                   NaN
# 11     Everyone loves a clown... some more than others.
# 16                      Everyone has something to hide.
# ...                                                 ...
# 2178  Even The Perfect Serial Killer Eventually Leav...
# 2182                       Do you want to meet a ghost?
# 2205                                                NaN
# 2222                       No Food. No Men. No Clothes.
# 2225  The only thing stranger than this family is......
#
#                          title  video  vote_average vote_count certification
# 5               Chinese Coffee    0.0         6.900       46.0             R
# 6             Heavy Metal 2000    0.0         6.093      156.0             R
# 7                     Love 101    0.0         0.000        0.0             R
# 11                      Vulgar    0.0         5.400       42.0             R
# 16    The Million Dollar Hotel    0.0         5.915      254.0             R
# ...                        ...    ...           ...        ...           ...
# 2178               Crime Scene    0.0         1.000        1.0             R
# 2182                     Pulse    0.0         6.557      335.0             R
# 2205               Shadow Fury    0.0         6.700        7.0             R
# 2222       Bare Naked Survivor    0.0         2.700        7.0             R
# 2225                 Visitor Q    0.0         6.500      374.0             R
#
# [674 rows x 26 columns]

# %%
#average revenue of G certified movies

df_groupedG = tmdb_results.groupby(filter_G)['revenue'].mean()
print (df_groupedG)
# Out:
# certification
# False    1.188155e+07
# True     8.190920e+07
# Name: revenue, dtype: float64

# %%
#average revenue of PG certified movies

df_groupedPG = tmdb_results.groupby(filter_PG)['revenue'].mean()
print (df_groupedPG)
# Out:
# certification
# False    1.094053e+07
# True     7.048362e+07
# Name: revenue, dtype: float64

# %%
#average revenue of PG13 certified movies

df_groupedPG13 = tmdb_results.groupby(filter_PG13)['revenue'].mean()
print (df_groupedPG13)
# Out:
# certification
# False    7.379060e+06
# True     7.256080e+07
# Name: revenue, dtype: float64

# %%
#average revenue of R certified movies

df_groupedR = tmdb_results.groupby(filter_R)['revenue'].mean()
print (df_groupedR)
# Out:
# certification
# False    1.133505e+07
# True     1.744905e+07
# Name: revenue, dtype: float64

# %%
#average budget for each certification category

#average budget of G certified movies
df2_groupedG = tmdb_results.groupby(filter_G)['budget'].mean()
print (df2_groupedG)
# Out:
# certification
# False    5.691742e+06
# True     2.450000e+07
# Name: budget, dtype: float64

# %%
#average budget of PG certified movies
df2_groupedPG = tmdb_results.groupby(filter_PG)['budget'].mean()
print (df2_groupedPG)
# Out:
# certification
# False    5.331946e+06
# True     2.532717e+07
# Name: budget, dtype: float64

# %%
#average budget of PG13 certified movies
df2_groupedPG13 = tmdb_results.groupby(filter_PG13)['budget'].mean()
print (df2_groupedPG13)
# Out:
# certification
# False    3.685654e+06
# True     3.126950e+07
# Name: budget, dtype: float64

# %%
#average budget of R certified movies
df2_groupedR = tmdb_results.groupby(filter_R)['budget'].mean()
print (df2_groupedR)
# Out:
# certification
# False    4.744884e+06
# True     1.047049e+07
# Name: budget, dtype: float64
